# %%
import requests
import pandas as pd

# %%
# btc current data
url = "https://api.binance.com/api/v3/ticker/24hr"
params = {"symbol": "BTCUSDT"}
r = requests.get(url, params=params)
data = r.json()
price = data["lastPrice"]
change = data["priceChangePercent"]

# %%
r.json()
# Out:
# {'symbol': 'BTCUSDT',
#  'priceChange': '949.98000000',
#  'priceChangePercent': '1.218',
#  'weightedAvgPrice': '78506.40675448',
#  'prevClosePrice': '77976.00000000',
#  'lastPrice': '78925.99000000',
#  'lastQty': '0.00883000',
#  'bidPrice': '78925.99000000',
#  'bidQty': '0.28945000',
#  'askPrice': '78926.00000000',
#  'askQty': '6.23036000',
#  'openPrice': '77976.01000000',
#  'highPrice': '79250.00000000',
#  'lowPrice': '77675.04000000',
#  'volume': '14950.84303000',
#  'quoteVolume': '1173736964.23555090',
#  'openTime': 1788157990001,
#  'closeTime': 1788244390001,
#  'firstId': 6638888763,
#  'lastId': 6642761745,
#  'count': 3872983}
