# %%
import requests
import pandas as pd

# %%
# btc current data
url = "https://api.binance.com/api/v3/ticker/24hr"
params = {"symbol": "BTCUSDT"}
r = requests.get(url, params=params)
data = r.json()
price = data["lastPrice"]
change = data["priceChangePercent"]

# %%
url = "https://api.coingecko.com/api/v3/simple/price?ids=bitcoin,tether,usd-coin&vs_currencies=usd&include_24hr_change=true"
r = requests.get(url, params=params)
data = r.json()
data
# Out:
# {'bitcoin': {'usd': 77838, 'usd_24h_change': -0.8120765604008213},
#  'tether': {'usd': 0.999711, 'usd_24h_change': -0.0037960607353861127},
#  'usd-coin': {'usd': 0.999858, 'usd_24h_change': 0.0008339762756934229}}
